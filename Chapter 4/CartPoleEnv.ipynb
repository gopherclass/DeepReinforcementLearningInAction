# %%
from gym.envs.classic_control.cartpole import CartPoleEnv
import gym

# %%
import torch
import math

# %% [markdown]
# # Creating CartPoleEnv() object

# %%
env_v0 = gym.make('CartPole-v0')
env_v1 = gym.make('CartPole-v1')
env_raw = CartPoleEnv()
env = env_raw

print(' v0', '=>', env_v0)
print('\t', 'max_episode_steps = {}'.format(env_v0.spec.max_episode_steps))
print('\t', 'reward_threshold  = {}'.format(env_v0.spec.reward_threshold))
print(' v1', '=>', env_v1)
print('\t', 'max_episode_steps = {}'.format(env_v1.spec.max_episode_steps))
print('\t', 'reward_threshold  = {}'.format(env_v1.spec.reward_threshold))
print('env', '=>', env)
# Out:
#  v0 => <TimeLimit<CartPoleEnv<CartPole-v0>>>
# 	 max_episode_steps = 200
# 	 reward_threshold  = 195.0
#  v1 => <TimeLimit<CartPoleEnv<CartPole-v1>>>
# 	 max_episode_steps = 500
# 	 reward_threshold  = 475.0
# env => <CartPoleEnv instance>

# %%
env.seed(1)
# Out:
# [1]

# %% [markdown]
# # State
# 1. Cart position (x)
# 2. Cart velocity (x_dot)
# 3. Pole angle (theta)
# 4. Rate of changes of the angle (theta_dot)

# %%
state = env.reset()
print(state)
print(env.state)
# Out:
# [ 0.03073904  0.00145001 -0.03088818 -0.03131252]
# [ 0.03073904  0.00145001 -0.03088818 -0.03131252]

# %% [markdown]
# # Observation

# %%
def format_state(state):
    x, x_dot, theta, theta_dot = state
    deg = math.degrees(theta)
    return "(x = {:+.4f}, dx = {:+.4f}, θ = {:+8.4f}, dθ = {:+.4f})".format(
        x, x_dot, deg, theta_dot)

# %%
ACTION_LEFT = 0
ACTION_RIGHT = 1

# %%
state = env.reset()
done = False
t = 0
print('initial state', '->', format_state(state))
while not done:
    state, reward, done, info = env.step(ACTION_LEFT)
    print('t = {:3}'.format(t), '->', format_state(state), reward, done, info)
    t += 1
# Out:
# initial state -> (x = +0.0003, dx = +0.0350, θ =  -2.6161, dθ = +0.0484)
# t =   0 -> (x = +0.0010, dx = -0.1595, θ =  -2.5606, dθ = +0.3264) 1.0 False {}
# t =   1 -> (x = -0.0022, dx = -0.3539, θ =  -2.1867, dθ = +0.6046) 1.0 False {}
# t =   2 -> (x = -0.0093, dx = -0.5485, θ =  -1.4938, dθ = +0.8850) 1.0 False {}
# t =   3 -> (x = -0.0203, dx = -0.7432, θ =  -0.4797, dθ = +1.1694) 1.0 False {}
# t =   4 -> (x = -0.0351, dx = -0.9383, θ =  +0.8604, dθ = +1.4595) 1.0 False {}
# t =   5 -> (x = -0.0539, dx = -1.1336, θ =  +2.5328, dθ = +1.7568) 1.0 False {}
# t =   6 -> (x = -0.0766, dx = -1.3292, θ =  +4.5459, dθ = +2.0629) 1.0 False {}
# t =   7 -> (x = -0.1032, dx = -1.5250, θ =  +6.9098, dθ = +2.3790) 1.0 False {}
# t =   8 -> (x = -0.1337, dx = -1.7210, θ =  +9.6360, dθ = +2.7062) 1.0 False {}
# t =   9 -> (x = -0.1681, dx = -1.9168, θ = +12.7371, dθ = +3.0451) 1.0 True {}

# %% [markdown]
# # TimeLimit
#
# https://github.com/openai/gym/blob/master/gym/wrappers/time_limit.py#L19
#
# TimeLimit.truncated

# %%
import cartpole

# %%
checkpoint = torch.load('Conv-v3.pt')
policy = cartpole.ConvNet4()
policy.load_state_dict(checkpoint['policy'])
# Out:
# <All keys matched successfully>

# %%
checkpoint = torch.load('FC-150-v1.pt')
policy = cartpole.FCNet0()
policy.load_state_dict(checkpoint['policy'])
# Out:
# <All keys matched successfully>

# %%
state = env_v0.reset()
done = False
t = 0
print('initial state', '->', format_state(state))
while not done:
    act_prob = cartpole.ask(policy, state)
    act = cartpole.choice_act(act_prob)
    state, reward, done, info = env_v0.step(act)
    print('t = {:3}'.format(t), '->', format_state(state), reward, done, info, act_prob.data.numpy())
    t += 1
# Out:
# initial state -> (x = -0.0409, dx = +0.0271, θ =  -0.4716, dθ = -0.0291)
# t =   0 -> (x = -0.0404, dx = -0.1679, θ =  -0.5050, dθ = +0.2609) 1.0 False {} [9.99865564e-01 1.34435786e-04]
# t =   1 -> (x = -0.0438, dx = +0.0273, θ =  -0.2060, dθ = -0.0345) 1.0 False {} [0.00273336 0.99726664]
# t =   2 -> (x = -0.0432, dx = -0.1677, θ =  -0.2456, dθ = +0.2570) 1.0 False {} [9.99867864e-01 1.32135932e-04]
# t =   3 -> (x = -0.0466, dx = +0.0274, θ =  +0.0489, dθ = -0.0370) 1.0 False {} [0.00249785 0.99750215]
# t =   4 -> (x = -0.0460, dx = -0.1677, θ =  +0.0065, dθ = +0.2559) 1.0 False {} [9.99863565e-01 1.36434550e-04]
# t =   5 -> (x = -0.0494, dx = +0.0274, θ =  +0.2998, dθ = -0.0367) 1.0 False {} [0.00199504 0.99800496]
# t =   6 -> (x = -0.0488, dx = -0.1678, θ =  +0.2577, dθ = +0.2576) 1.0 False {} [9.99851832e-01 1.48167766e-04]
# t =   7 -> (x = -0.0522, dx = +0.0273, θ =  +0.5530, dθ = -0.0336) 1.0 False {} [0.00146397 0.99853603]
# t =   8 -> (x = -0.0516, dx = -0.1680, θ =  +0.5144, dθ = +0.2621) 1.0 False {} [9.99830220e-01 1.69779822e-04]
# t =   9 -> (x = -0.0550, dx = +0.0270, θ =  +0.8147, dθ = -0.0278) 1.0 False {} [9.77560068e-04 9.99022440e-01]
# t =  10 -> (x = -0.0545, dx = -0.1683, θ =  +0.7829, dθ = +0.2694) 1.0 False {} [9.99793693e-01 2.06307172e-04]
# t =  11 -> (x = -0.0578, dx = +0.0266, θ =  +1.0916, dθ = -0.0190) 1.0 False {} [6.20509404e-04 9.99379491e-01]
# t =  12 -> (x = -0.0573, dx = -0.1688, θ =  +1.0698, dθ = +0.2797) 1.0 False {} [9.99732467e-01 2.67532996e-04]
# t =  13 -> (x = -0.0607, dx = +0.0261, θ =  +1.3903, dθ = -0.0071) 1.0 False {} [3.71746584e-04 9.99628253e-01]
# t =  14 -> (x = -0.0601, dx = -0.1694, θ =  +1.3822, dθ = +0.2932) 1.0 False {} [9.99627110e-01 3.72889622e-04]
# t =  15 -> (x = -0.0635, dx = +0.0254, θ =  +1.7182, dθ = +0.0082) 1.0 False {} [2.22410735e-04 9.99777589e-01]
# t =  16 -> (x = -0.0630, dx = -0.1701, θ =  +1.7275, dθ = +0.3102) 1.0 False {} [9.99420234e-01 5.79766304e-04]
# t =  17 -> (x = -0.0664, dx = +0.0245, θ =  +2.0830, dθ = +0.0272) 1.0 False {} [1.41902557e-04 9.99858097e-01]
# t =  18 -> (x = -0.0659, dx = -0.1711, θ =  +2.1141, dθ = +0.3311) 1.0 False {} [0.99888979 0.00111021]
# t =  19 -> (x = -0.0694, dx = +0.0235, θ =  +2.4935, dθ = +0.0503) 1.0 False {} [9.06158524e-05 9.99909384e-01]
# t =  20 -> (x = -0.0689, dx = -0.1722, θ =  +2.5511, dθ = +0.3564) 1.0 False {} [0.99749992 0.00250008]
# t =  21 -> (x = -0.0723, dx = +0.0222, θ =  +2.9594, dθ = +0.0780) 1.0 False {} [5.53756176e-05 9.99944624e-01]
# t =  22 -> (x = -0.0719, dx = -0.1736, θ =  +3.0489, dθ = +0.3866) 1.0 False {} [0.98780545 0.01219455]
# t =  23 -> (x = -0.0754, dx = +0.0207, θ =  +3.4918, dθ = +0.1111) 1.0 False {} [3.02990065e-05 9.99969701e-01]
# t =  24 -> (x = -0.0749, dx = +0.2149, θ =  +3.6192, dθ = -0.1617) 1.0 False {} [0.31001925 0.68998075]
# t =  25 -> (x = -0.0706, dx = +0.0190, θ =  +3.4338, dθ = +0.1502) 1.0 False {} [9.99943191e-01 5.68086771e-05]
# t =  26 -> (x = -0.0703, dx = +0.2132, θ =  +3.6059, dθ = -0.1230) 1.0 False {} [0.00912595 0.99087405]
# t =  27 -> (x = -0.0660, dx = +0.0172, θ =  +3.4650, dθ = +0.1889) 1.0 False {} [9.99911477e-01 8.85232917e-05]
# t =  28 -> (x = -0.0657, dx = +0.2114, θ =  +3.6814, dθ = -0.0842) 1.0 False {} [6.21448530e-04 9.99378551e-01]
# t =  29 -> (x = -0.0614, dx = +0.0154, θ =  +3.5849, dθ = +0.2281) 1.0 False {} [9.99853253e-01 1.46747020e-04]
# t =  30 -> (x = -0.0611, dx = +0.2096, θ =  +3.8463, dθ = -0.0442) 1.0 False {} [2.30925681e-04 9.99769074e-01]
# t =  31 -> (x = -0.0569, dx = +0.0136, θ =  +3.7956, dθ = +0.2689) 1.0 False {} [9.99708642e-01 2.91357596e-04]
# t =  32 -> (x = -0.0566, dx = +0.2077, θ =  +4.1037, dθ = -0.0022) 1.0 False {} [1.15347594e-04 9.99884652e-01]
# t =  33 -> (x = -0.0525, dx = +0.0117, θ =  +4.1012, dθ = +0.3122) 1.0 False {} [0.99840035 0.00159965]
# t =  34 -> (x = -0.0523, dx = +0.2057, θ =  +4.4589, dθ = +0.0429) 1.0 False {} [5.40145290e-05 9.99945985e-01]
# t =  35 -> (x = -0.0481, dx = +0.0095, θ =  +4.5081, dθ = +0.3591) 1.0 False {} [0.89363695 0.10636305]
# t =  36 -> (x = -0.0480, dx = +0.2035, θ =  +4.9196, dθ = +0.0922) 1.0 False {} [2.14018605e-05 9.99978598e-01]
# t =  37 -> (x = -0.0439, dx = +0.3973, θ =  +5.0252, dθ = -0.1722) 1.0 False {} [0.01784004 0.98215996]
# t =  38 -> (x = -0.0359, dx = +0.2010, θ =  +4.8279, dθ = +0.1468) 1.0 False {} [9.99853333e-01 1.46666709e-04]
# t =  39 -> (x = -0.0319, dx = +0.3948, θ =  +4.9962, dθ = -0.1181) 1.0 False {} [4.80378919e-04 9.99519621e-01]
# t =  40 -> (x = -0.0240, dx = +0.1986, θ =  +4.8608, dθ = +0.2007) 1.0 False {} [9.99705535e-01 2.94464794e-04]
# t =  41 -> (x = -0.0201, dx = +0.3924, θ =  +5.0908, dθ = -0.0640) 1.0 False {} [1.70282901e-04 9.99829717e-01]
# t =  42 -> (x = -0.0122, dx = +0.1961, θ =  +5.0175, dθ = +0.2553) 1.0 False {} [9.99227808e-01 7.72192494e-04]
# t =  43 -> (x = -0.0083, dx = +0.3899, θ =  +5.3100, dθ = -0.0085) 1.0 False {} [7.05533857e-05 9.99929447e-01]
# t =  44 -> (x = -0.0005, dx = +0.1935, θ =  +5.3003, dθ = +0.3119) 1.0 False {} [0.89305973 0.10694027]
# t =  45 -> (x = +0.0034, dx = +0.3872, θ =  +5.6577, dθ = +0.0498) 1.0 False {} [2.27451010e-05 9.99977255e-01]
# t =  46 -> (x = +0.0111, dx = +0.5808, θ =  +5.7148, dθ = -0.2102) 1.0 False {} [0.01697876 0.98302124]
# t =  47 -> (x = +0.0227, dx = +0.3844, θ =  +5.4739, dθ = +0.1122) 1.0 False {} [9.99552073e-01 4.47926641e-04]
# t =  48 -> (x = +0.0304, dx = +0.5780, θ =  +5.6025, dθ = -0.1489) 1.0 False {} [4.51102727e-04 9.99548897e-01]
# t =  49 -> (x = +0.0420, dx = +0.3817, θ =  +5.4319, dθ = +0.1730) 1.0 False {} [9.99025637e-01 9.74362716e-04]
# t =  50 -> (x = +0.0496, dx = +0.5753, θ =  +5.6302, dθ = -0.0883) 1.0 False {} [1.44968326e-04 9.99855032e-01]
# t =  51 -> (x = +0.0611, dx = +0.3789, θ =  +5.5289, dθ = +0.2337) 1.0 False {} [0.99092436 0.00907564]
# t =  52 -> (x = +0.0687, dx = +0.5726, θ =  +5.7967, dθ = -0.0271) 1.0 False {} [5.63517236e-05 9.99943648e-01]
# t =  53 -> (x = +0.0802, dx = +0.7661, θ =  +5.7657, dθ = -0.2862) 1.0 False {} [0.23493112 0.76506888]
# t =  54 -> (x = +0.0955, dx = +0.5697, θ =  +5.4377, dθ = +0.0364) 1.0 False {} [9.99179771e-01 8.20228846e-04]
# t =  55 -> (x = +0.1069, dx = +0.7633, θ =  +5.4794, dθ = -0.2249) 1.0 False {} [0.00582902 0.99417098]
# t =  56 -> (x = +0.1221, dx = +0.9570, θ =  +5.2217, dθ = -0.4859) 1.0 False {} [0.99588435 0.00411565]
# t =  57 -> (x = +0.1413, dx = +0.7607, θ =  +4.6649, dθ = -0.1660) 1.0 False {} [9.99885565e-01 1.14435372e-04]
# t =  58 -> (x = +0.1565, dx = +0.5645, θ =  +4.4748, dθ = +0.1513) 1.0 False {} [0.97305603 0.02694397]
# t =  59 -> (x = +0.1678, dx = +0.7584, θ =  +4.6481, dθ = -0.1158) 1.0 False {} [2.44996683e-04 9.99755003e-01]
# t =  60 -> (x = +0.1830, dx = +0.5622, θ =  +4.5154, dθ = +0.2013) 1.0 False {} [0.87480602 0.12519398]
# t =  61 -> (x = +0.1942, dx = +0.7561, θ =  +4.7461, dθ = -0.0655) 1.0 False {} [8.97732587e-05 9.99910227e-01]
# t =  62 -> (x = +0.2093, dx = +0.9500, θ =  +4.6711, dθ = -0.3309) 1.0 False {} [0.26405845 0.73594155]
# t =  63 -> (x = +0.2283, dx = +0.7538, θ =  +4.2919, dθ = -0.0137) 1.0 False {} [0.99844818 0.00155182]
# t =  64 -> (x = +0.2434, dx = +0.9478, θ =  +4.2762, dθ = -0.2818) 1.0 False {} [0.01663089 0.98336911]
# t =  65 -> (x = +0.2624, dx = +0.7517, θ =  +3.9532, dθ = +0.0334) 1.0 False {} [0.99263499 0.00736501]
# t =  66 -> (x = +0.2774, dx = +0.9457, θ =  +3.9915, dθ = -0.2367) 1.0 False {} [0.00202385 0.99797615]
# t =  67 -> (x = +0.2963, dx = +0.7497, θ =  +3.7203, dθ = +0.0771) 1.0 False {} [0.93409215 0.06590785]
# t =  68 -> (x = +0.3113, dx = +0.9438, θ =  +3.8086, dθ = -0.1944) 1.0 False {} [5.91352037e-04 9.99408648e-01]
# t =  69 -> (x = +0.3302, dx = +1.1379, θ =  +3.5859, dθ = -0.4654) 1.0 False {} [0.75370299 0.24629701]
# t =  70 -> (x = +0.3529, dx = +0.9420, θ =  +3.0526, dθ = -0.1537) 1.0 False {} [9.99638869e-01 3.61131369e-04]
# t =  71 -> (x = +0.3718, dx = +1.1363, θ =  +2.8765, dθ = -0.4291) 1.0 False {} [0.6318608 0.3681392]
# t =  72 -> (x = +0.3945, dx = +0.9405, θ =  +2.3848, dθ = -0.1210) 1.0 False {} [9.99324705e-01 6.75294524e-04]
# t =  73 -> (x = +0.4133, dx = +1.1350, θ =  +2.2461, dθ = -0.4003) 1.0 False {} [0.55818513 0.44181487]
# t =  74 -> (x = +0.4360, dx = +0.9394, θ =  +1.7875, dθ = -0.0955) 1.0 False {} [0.99897204 0.00102796]
# t =  75 -> (x = +0.4548, dx = +1.1340, θ =  +1.6780, dθ = -0.3782) 1.0 False {} [0.4051433 0.5948567]
# t =  76 -> (x = +0.4775, dx = +0.9385, θ =  +1.2447, dθ = -0.0764) 1.0 False {} [0.99896871 0.00103129]
# t =  77 -> (x = +0.4962, dx = +1.1333, θ =  +1.1572, dθ = -0.3621) 1.0 False {} [0.17870063 0.82129937]
# t =  78 -> (x = +0.5189, dx = +0.9379, θ =  +0.7422, dθ = -0.0632) 1.0 False {} [9.99020369e-01 9.79630524e-04]
# t =  79 -> (x = +0.5377, dx = +1.1328, θ =  +0.6698, dθ = -0.3517) 1.0 False {} [0.10114256 0.89885744]
# t =  80 -> (x = +0.5603, dx = +0.9375, θ =  +0.2667, dθ = -0.0554) 1.0 False {} [9.99068024e-01 9.31976237e-04]
# t =  81 -> (x = +0.5791, dx = +1.1326, θ =  +0.2033, dθ = -0.3466) 1.0 False {} [0.07589367 0.92410633]
# t =  82 -> (x = +0.6017, dx = +0.9374, θ =  -0.1939, dθ = -0.0528) 1.0 False {} [9.99191088e-01 8.08912385e-04]
# t =  83 -> (x = +0.6205, dx = +1.1326, θ =  -0.2544, dθ = -0.3465) 1.0 False {} [0.07447348 0.92552652]
# t =  84 -> (x = +0.6431, dx = +0.9375, θ =  -0.6515, dθ = -0.0553) 1.0 False {} [9.99357531e-01 6.42469130e-04]
# t =  85 -> (x = +0.6619, dx = +1.1328, θ =  -0.7148, dθ = -0.3515) 1.0 False {} [0.09897351 0.90102649]
# t =  86 -> (x = +0.6845, dx = +0.9379, θ =  -1.1176, dθ = -0.0628) 1.0 False {} [9.99528959e-01 4.71040849e-04]
# t =  87 -> (x = +0.7033, dx = +0.7430, θ =  -1.1896, dθ = +0.2237) 1.0 False {} [0.19415743 0.80584257]
# t =  88 -> (x = +0.7182, dx = +0.9385, θ =  -0.9332, dθ = -0.0755) 1.0 False {} [2.78121765e-05 9.99972188e-01]
# t =  89 -> (x = +0.7369, dx = +0.7436, θ =  -1.0197, dθ = +0.2120) 1.0 False {} [0.24889896 0.75110104]
# t =  90 -> (x = +0.7518, dx = +0.9389, θ =  -0.7768, dθ = -0.0862) 1.0 False {} [2.60559721e-05 9.99973944e-01]
# t =  91 -> (x = +0.7706, dx = +0.7440, θ =  -0.8756, dθ = +0.2021) 1.0 False {} [0.29860071 0.70139929]
# t =  92 -> (x = +0.7855, dx = +0.9394, θ =  -0.6439, dθ = -0.0953) 1.0 False {} [2.51809777e-05 9.99974819e-01]
# t =  93 -> (x = +0.8042, dx = +1.1346, θ =  -0.7532, dθ = -0.3915) 1.0 False {} [0.33846449 0.66153551]
# t =  94 -> (x = +0.8269, dx = +0.9397, θ =  -1.2018, dθ = -0.1030) 1.0 False {} [9.99788709e-01 2.11291143e-04]
# t =  95 -> (x = +0.8457, dx = +0.7449, θ =  -1.3199, dθ = +0.1830) 1.0 False {} [0.65622476 0.34377524]
# t =  96 -> (x = +0.8606, dx = +0.9403, θ =  -1.1102, dθ = -0.1169) 1.0 False {} [4.0760127e-05 9.9995924e-01]
# t =  97 -> (x = +0.8794, dx = +1.1357, θ =  -1.2441, dθ = -0.4156) 1.0 False {} [0.7935335 0.2064665]
# t =  98 -> (x = +0.9021, dx = +0.9409, θ =  -1.7204, dθ = -0.1299) 1.0 False {} [9.99874884e-01 1.25115587e-04]
# t =  99 -> (x = +0.9210, dx = +0.7462, θ =  -1.8692, dθ = +0.1532) 1.0 False {} [0.9698043 0.0301957]
# t = 100 -> (x = +0.9359, dx = +0.9418, θ =  -1.6936, dθ = -0.1496) 1.0 False {} [1.39644995e-04 9.99860355e-01]
# t = 101 -> (x = +0.9547, dx = +0.7471, θ =  -1.8650, dθ = +0.1336) 1.0 False {} [0.99225707 0.00774293]
# t = 102 -> (x = +0.9697, dx = +0.9427, θ =  -1.7119, dθ = -0.1691) 1.0 False {} [2.57605460e-04 9.99742395e-01]
# t = 103 -> (x = +0.9885, dx = +0.7480, θ =  -1.9057, dθ = +0.1140) 1.0 False {} [0.9959931 0.0040069]
# t = 104 -> (x = +1.0035, dx = +0.9436, θ =  -1.7751, dθ = -0.1890) 1.0 False {} [4.93453870e-04 9.99506546e-01]
# t = 105 -> (x = +1.0224, dx = +0.7489, θ =  -1.9917, dθ = +0.0937) 1.0 False {} [0.99747947 0.00252053]
# t = 106 -> (x = +1.0373, dx = +0.9445, θ =  -1.8843, dθ = -0.2097) 1.0 False {} [9.52660069e-04 9.99047340e-01]
# t = 107 -> (x = +1.0562, dx = +0.7499, θ =  -2.1247, dθ = +0.0724) 1.0 False {} [0.99849093 0.00150907]
# t = 108 -> (x = +1.0712, dx = +0.9455, θ =  -2.0417, dθ = -0.2317) 1.0 False {} [0.00187991 0.99812009]
# t = 109 -> (x = +1.0901, dx = +0.7509, θ =  -2.3072, dθ = +0.0495) 1.0 False {} [9.99151874e-01 8.48126048e-04]
# t = 110 -> (x = +1.1052, dx = +0.9466, θ =  -2.2505, dθ = -0.2556) 1.0 False {} [0.00387182 0.99612818]
# t = 111 -> (x = +1.1241, dx = +0.7521, θ =  -2.5434, dθ = +0.0244) 1.0 False {} [9.99543256e-01 4.56744118e-04]
# t = 112 -> (x = +1.1391, dx = +0.9478, θ =  -2.5154, dθ = -0.2819) 1.0 False {} [0.00848128 0.99151872]
# t = 113 -> (x = +1.1581, dx = +0.7533, θ =  -2.8385, dθ = -0.0034) 1.0 False {} [9.99675115e-01 3.24885262e-04]
# t = 114 -> (x = +1.1732, dx = +0.9491, θ =  -2.8424, dθ = -0.3113) 1.0 False {} [0.03541147 0.96458853]
# t = 115 -> (x = +1.1921, dx = +0.7548, θ =  -3.1991, dθ = -0.0347) 1.0 False {} [9.99770920e-01 2.29080463e-04]
# t = 116 -> (x = +1.2072, dx = +0.9506, θ =  -3.2389, dθ = -0.3444) 1.0 False {} [0.3203903 0.6796097]
# t = 117 -> (x = +1.2262, dx = +0.7564, θ =  -3.6336, dθ = -0.0701) 1.0 False {} [9.99841665e-01 1.58334577e-04]
# t = 118 -> (x = +1.2414, dx = +0.5622, θ =  -3.7139, dθ = +0.2019) 1.0 False {} [0.9073812 0.0926188]
# t = 119 -> (x = +1.2526, dx = +0.7582, θ =  -3.4825, dθ = -0.1105) 1.0 False {} [4.66549669e-04 9.99533450e-01]
# t = 120 -> (x = +1.2678, dx = +0.5640, θ =  -3.6091, dθ = +0.1624) 1.0 False {} [0.96236248 0.03763752]
# t = 121 -> (x = +1.2791, dx = +0.7599, θ =  -3.4230, dθ = -0.1494) 1.0 False {} [0.00112653 0.99887347]
# t = 122 -> (x = +1.2943, dx = +0.5657, θ =  -3.5942, dθ = +0.1238) 1.0 False {} [0.98804928 0.01195072]
# t = 123 -> (x = +1.3056, dx = +0.7617, θ =  -3.4524, dθ = -0.1880) 1.0 False {} [0.00278191 0.99721809]
# t = 124 -> (x = +1.3208, dx = +0.5675, θ =  -3.6678, dθ = +0.0851) 1.0 False {} [0.99654212 0.00345788]
# t = 125 -> (x = +1.3322, dx = +0.7635, θ =  -3.5703, dθ = -0.2271) 1.0 False {} [0.00862879 0.99137121]
# t = 126 -> (x = +1.3474, dx = +0.5693, θ =  -3.8305, dθ = +0.0453) 1.0 False {} [0.9985326 0.0014674]
# t = 127 -> (x = +1.3588, dx = +0.7653, θ =  -3.7786, dθ = -0.2677) 1.0 False {} [0.05442217 0.94557783]
# t = 128 -> (x = +1.3741, dx = +0.5712, θ =  -4.0853, dθ = +0.0035) 1.0 False {} [9.99247273e-01 7.52727028e-04]
# t = 129 -> (x = +1.3855, dx = +0.3771, θ =  -4.0813, dθ = +0.2728) 1.0 False {} [0.54231401 0.45768599]
# t = 130 -> (x = +1.3931, dx = +0.5732, θ =  -3.7687, dθ = -0.0414) 1.0 False {} [1.98200677e-04 9.99801799e-01]
# t = 131 -> (x = +1.4045, dx = +0.3791, θ =  -3.8161, dθ = +0.2298) 1.0 False {} [0.8849886 0.1150114]
# t = 132 -> (x = +1.4121, dx = +0.5751, θ =  -3.5528, dθ = -0.0831) 1.0 False {} [4.48089284e-04 9.99551911e-01]
# t = 133 -> (x = +1.4236, dx = +0.3809, θ =  -3.6480, dθ = +0.1894) 1.0 False {} [0.9433562 0.0566438]
# t = 134 -> (x = +1.4312, dx = +0.5769, θ =  -3.4310, dθ = -0.1227) 1.0 False {} [0.00100716 0.99899284]
# t = 135 -> (x = +1.4428, dx = +0.3827, θ =  -3.5717, dθ = +0.1505) 1.0 False {} [0.9726435 0.0273565]
# t = 136 -> (x = +1.4504, dx = +0.5786, θ =  -3.3992, dθ = -0.1612) 1.0 False {} [0.00244816 0.99755184]
# t = 137 -> (x = +1.4620, dx = +0.3844, θ =  -3.5839, dθ = +0.1122) 1.0 False {} [0.98727529 0.01272471]
# t = 138 -> (x = +1.4697, dx = +0.5804, θ =  -3.4553, dθ = -0.1995) 1.0 False {} [0.00904358 0.99095642]
# t = 139 -> (x = +1.4813, dx = +0.3861, θ =  -3.6839, dθ = +0.0735) 1.0 False {} [0.99469651 0.00530349]
# t = 140 -> (x = +1.4890, dx = +0.5821, θ =  -3.5997, dθ = -0.2387) 1.0 False {} [0.06001472 0.93998528]
# t = 141 -> (x = +1.5007, dx = +0.3880, θ =  -3.8732, dθ = +0.0335) 1.0 False {} [0.99764239 0.00235761]
# t = 142 -> (x = +1.5084, dx = +0.1939, θ =  -3.8348, dθ = +0.3041) 1.0 False {} [0.45212108 0.54787892]
# t = 143 -> (x = +1.5123, dx = +0.3899, θ =  -3.4863, dθ = -0.0089) 1.0 False {} [1.49945134e-04 9.99850055e-01]
# t = 144 -> (x = +1.5201, dx = +0.1957, θ =  -3.4965, dθ = +0.2640) 1.0 False {} [0.84975501 0.15024499]
# t = 145 -> (x = +1.5240, dx = +0.3916, θ =  -3.1940, dθ = -0.0473) 1.0 False {} [2.98285991e-04 9.99701714e-01]
# t = 146 -> (x = +1.5318, dx = +0.1973, θ =  -3.2482, dθ = +0.2273) 1.0 False {} [0.91877907 0.08122093]
# t = 147 -> (x = +1.5358, dx = +0.3932, θ =  -2.9878, dθ = -0.0827) 1.0 False {} [5.88068153e-04 9.99411932e-01]
# t = 148 -> (x = +1.5437, dx = +0.1989, θ =  -3.0826, dθ = +0.1931) 1.0 False {} [0.95282185 0.04717815]
# t = 149 -> (x = +1.5476, dx = +0.3947, θ =  -2.8614, dθ = -0.1161) 1.0 False {} [0.00121725 0.99878275]
# t = 150 -> (x = +1.5555, dx = +0.2004, θ =  -2.9944, dθ = +0.1604) 1.0 False {} [0.97277123 0.02722877]
# t = 151 -> (x = +1.5595, dx = +0.3962, θ =  -2.8106, dθ = -0.1483) 1.0 False {} [0.00326242 0.99673758]
# t = 152 -> (x = +1.5675, dx = +0.2018, θ =  -2.9805, dθ = +0.1285) 1.0 False {} [0.98476463 0.01523537]
# t = 153 -> (x = +1.5715, dx = +0.3976, θ =  -2.8333, dθ = -0.1801) 1.0 False {} [0.0110248 0.9889752]
# t = 154 -> (x = +1.5795, dx = +0.5934, θ =  -3.0397, dθ = -0.4880) 1.0 False {} [0.99066084 0.00933916]
# t = 155 -> (x = +1.5913, dx = +0.3991, θ =  -3.5988, dθ = -0.2125) 1.0 False {} [9.99890327e-01 1.09673033e-04]
# t = 156 -> (x = +1.5993, dx = +0.2049, θ =  -3.8423, dθ = +0.0598) 1.0 False {} [0.99416529 0.00583471]
# t = 157 -> (x = +1.6034, dx = +0.0108, θ =  -3.7738, dθ = +0.3306) 1.0 False {} [0.53261498 0.46738502]
# t = 158 -> (x = +1.6036, dx = +0.2068, θ =  -3.3950, dθ = +0.0178) 1.0 False {} [1.42979594e-04 9.99857020e-01]
# t = 159 -> (x = +1.6078, dx = +0.0126, θ =  -3.3746, dθ = +0.2913) 1.0 False {} [0.8388539 0.1611461]
# t = 160 -> (x = +1.6080, dx = +0.2085, θ =  -3.0408, dθ = -0.0194) 1.0 False {} [2.72396875e-04 9.99727603e-01]
# t = 161 -> (x = +1.6122, dx = +0.0142, θ =  -3.0631, dθ = +0.2561) 1.0 False {} [0.90653793 0.09346207]
# t = 162 -> (x = +1.6125, dx = +0.2100, θ =  -2.7696, dθ = -0.0530) 1.0 False {} [5.00246788e-04 9.99499753e-01]
# t = 163 -> (x = +1.6167, dx = +0.0156, θ =  -2.8303, dθ = +0.2241) 1.0 False {} [0.940981 0.059019]
# t = 164 -> (x = +1.6170, dx = +0.2114, θ =  -2.5736, dθ = -0.0838) 1.0 False {} [0.00106939 0.99893061]
# t = 165 -> (x = +1.6212, dx = +0.0170, θ =  -2.6696, dθ = +0.1944) 1.0 False {} [0.96222743 0.03777257]
# t = 166 -> (x = +1.6215, dx = +0.2127, θ =  -2.4468, dθ = -0.1126) 1.0 False {} [0.00251008 0.99748992]
# t = 167 -> (x = +1.6258, dx = +0.0182, θ =  -2.5758, dθ = +0.1663) 1.0 False {} [0.97587203 0.02412797]
# t = 168 -> (x = +1.6262, dx = +0.2140, θ =  -2.3853, dθ = -0.1402) 1.0 False {} [0.00655017 0.99344983]
# t = 169 -> (x = +1.6304, dx = +0.0195, θ =  -2.5459, dθ = +0.1390) 1.0 False {} [0.98468499 0.01531501]
# t = 170 -> (x = +1.6308, dx = +0.2152, θ =  -2.3866, dθ = -0.1673) 1.0 False {} [0.02170338 0.97829662]
# t = 171 -> (x = +1.6351, dx = +0.0207, θ =  -2.5783, dθ = +0.1119) 1.0 False {} [0.98746646 0.01253354]
# t = 172 -> (x = +1.6355, dx = +0.2164, θ =  -2.4501, dθ = -0.1946) 1.0 False {} [0.0799689 0.9200311]
# t = 173 -> (x = +1.6399, dx = +0.0220, θ =  -2.6730, dθ = +0.0843) 1.0 False {} [0.98822792 0.01177208]
# t = 174 -> (x = +1.6403, dx = -0.1725, θ =  -2.5764, dθ = +0.3619) 1.0 False {} [0.28959616 0.71040384]
# t = 175 -> (x = +1.6369, dx = +0.0233, θ =  -2.1617, dθ = +0.0554) 1.0 False {} [6.82861389e-05 9.99931714e-01]
# t = 176 -> (x = +1.6373, dx = -0.1713, θ =  -2.0983, dθ = +0.3359) 1.0 False {} [0.50285254 0.49714746]
# t = 177 -> (x = +1.6339, dx = +0.0243, θ =  -1.7133, dθ = +0.0319) 1.0 False {} [9.33351191e-05 9.99906665e-01]
# t = 178 -> (x = +1.6344, dx = -0.1704, θ =  -1.6767, dθ = +0.3150) 1.0 False {} [0.66786659 0.33213341]
# t = 179 -> (x = +1.6310, dx = +0.0252, θ =  -1.3157, dθ = +0.0133) 1.0 False {} [1.17836804e-04 9.99882163e-01]
# t = 180 -> (x = +1.6315, dx = -0.1696, θ =  -1.3005, dθ = +0.2986) 1.0 False {} [0.75949103 0.24050897]
# t = 181 -> (x = +1.6281, dx = +0.0258, θ =  -0.9583, dθ = -0.0011) 1.0 False {} [1.38286031e-04 9.99861714e-01]
# t = 182 -> (x = +1.6286, dx = -0.1691, θ =  -0.9596, dθ = +0.2862) 1.0 False {} [0.80238026 0.19761974]
# t = 183 -> (x = +1.6252, dx = +0.0263, θ =  -0.6316, dθ = -0.0117) 1.0 False {} [1.51538829e-04 9.99848461e-01]
# t = 184 -> (x = +1.6258, dx = -0.1687, θ =  -0.6450, dθ = +0.2775) 1.0 False {} [0.81796101 0.18203899]
# t = 185 -> (x = +1.6224, dx = +0.0266, θ =  -0.3271, dθ = -0.0187) 1.0 False {} [1.55519658e-04 9.99844480e-01]
# t = 186 -> (x = +1.6229, dx = -0.1684, θ =  -0.3485, dθ = +0.2722) 1.0 False {} [0.81536045 0.18463955]
# t = 187 -> (x = +1.6195, dx = +0.0268, θ =  -0.0367, dθ = -0.0224) 1.0 False {} [1.4966970e-04 9.9985033e-01]
# t = 188 -> (x = +1.6201, dx = -0.1683, θ =  -0.0624, dθ = +0.2700) 1.0 False {} [0.79439626 0.20560374]
# t = 189 -> (x = +1.6167, dx = +0.0268, θ =  +0.2471, dθ = -0.0230) 1.0 False {} [1.35038068e-04 9.99864962e-01]
# t = 190 -> (x = +1.6173, dx = -0.1684, θ =  +0.2207, dθ = +0.2711) 1.0 False {} [0.74575314 0.25424686]
# t = 191 -> (x = +1.6139, dx = +0.0267, θ =  +0.5313, dθ = -0.0204) 1.0 False {} [1.14011988e-04 9.99885988e-01]
# t = 192 -> (x = +1.6144, dx = -0.1686, θ =  +0.5079, dθ = +0.2752) 1.0 False {} [0.64886603 0.35113397]
# t = 193 -> (x = +1.6110, dx = +0.0264, θ =  +0.8233, dθ = -0.0147) 1.0 False {} [8.97651870e-05 9.99910235e-01]
# t = 194 -> (x = +1.6116, dx = +0.2213, θ =  +0.8064, dθ = -0.3028) 1.0 False {} [0.48269049 0.51730951]
# t = 195 -> (x = +1.6160, dx = +0.0260, θ =  +0.4594, dθ = -0.0057) 1.0 False {} [0.9886343 0.0113657]
# t = 196 -> (x = +1.6165, dx = -0.1692, θ =  +0.4529, dθ = +0.2895) 1.0 False {} [0.47955162 0.52044838]
# t = 197 -> (x = +1.6131, dx = +0.0258, θ =  +0.7846, dθ = -0.0007) 1.0 False {} [6.79782893e-05 9.99932022e-01]
# t = 198 -> (x = +1.6137, dx = -0.1695, θ =  +0.7838, dθ = +0.2963) 1.0 False {} [0.31337124 0.68662876]
# t = 199 -> (x = +1.6103, dx = +0.0254, θ =  +1.1233, dθ = +0.0079) 1.0 True {'TimeLimit.truncated': True} [4.93883645e-05 9.99950612e-01]

# %%
cartpole.sim(policy, env, limit=200, animation=True)
